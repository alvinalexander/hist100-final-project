# %% [markdown]
# # Our Project
#
# Hip-hop and rap are genres that have had unprecedented origin and evolution in the past forty years. “Hip-Hop Evolution” is a documentary series that does an incredible job in tracking thse origins and early manifestations. It cites that hip-hop and rap's narrative starts in the Southern Bronx of New Year City and follows the largest visionaries and musical innovators of the time up until 1994 when rap officially enters the “mainstream". The documentary functions as an anthropological escapade, relying on interviews with a broad range of individuals involved in the genre’s creation. It pieces together a narrative that explains how rap and hip hop emerged as both a technological and sociological innovation-- analyizing lyrical themes from the begining, as rap was first created for the exclusive purpose of party entertainment in the late 1970s, to how it became a medium for proposing commentary and reflection on the reality of poor neighborhoods and being Black American in the early 1990s. Though we believe the documentory has done an impressive job in tracing rap and hip-hop's origins, our project is interested in investigating the evolution of the genre after the series ends.
#
# #### We want to know how has rap and hip-hop has evolved since it entered the mainstream? How does this differ from its underground roots? And what sociological events have motivated recent modifications?
#
# ### Our hypothesis
#
# Many indivduals today would argue that rap and hip-hop is a genre that has always been concerned with commenting and reflecting on reality. The "Hip-Hop Evolution" cites that this is not necessarily true, reflection was something that had to be developed in rap, as the genre first manifested as a product of disco and partying.
#
# In rap's origins MCs dominated the social scene, writing music about partying and women to subsequently assert their status in the community. After the song, “The Message” by Grandmaster Flash and The Furious Five came out in 1982, rap and hip-hop saw a glimpse of what lyrical topics in the coming decade would discuss. The 1980s was a dynamic and difficult time for urban America, especially for impoverished black communities. Reaganomics, the emergence of crack, the War on Drugs, gang violence, and discrimination all had tremendous influence, and it was during this period that, for the first time, these issues began manifesting themselves in lyrics.
#
# Furthermore, as the documentary series comes to a close, it discusses how the popularity of rap and hip-hop was being spread throughout a variety of youth listeners in the United States. The heightened popularity seen in the early 1990s set presidency for a new type of rap and hip-hop, as rappers transitioned from underground artists to reaping the same fame and notoriety of pop stars.
#
# Give this consideration, we hypothesize that as rap and hip-hop entered the mainstream in the early 1990s, we will see a trend in lyrical content as it pivots away from the iteration of black American experiences, to more conventional themes seen in other popular music-- such as love/sex, fame, and status/power
#
# #### We believe that this question is best answered through computational analysis because computational analysis is fast, just as thorough as hand-coding, and will allow us the ability to look at an extensive corpus (80% of commercially successful hip-hop and rap songs in the past two decades).
#
#
# # Exploration Through What Means
#
# Our project first starts with topic-modeling, as we are looking to corroborate the themes noted throughout the documentary film “Hip-Hop Evolution”. Unfortunately, we are not able to analysize many rap or hip-hop lyrics from before 1989 because most of them were never publish or transcribed online. From here we will measure which of these interpreted categories have increased and decreased throughout time.
#
# After this we will be examining the more specific elements of our catergoies by comparing changes in particular words over time. We will be relying on LIWC dictionaries that have categories associated with our analysis from the topic-modeling computation to conduct a dictionary-method analysis. We acknowledge that this process has a potential for bias, in that involves speculative assumption that our interpreted topic modeling categories are correct, and that they relate to the LIWC dictionaries provided.
#
# Throughout these computational processes, we will be sublementing our findings on the evolution of mainstream rap and hip-hop with analysis and theortical explanations.

# %%
import pandas
from ast import literal_eval
import nltk
from nltk import word_tokenize
import matplotlib.pyplot as plt
import numpy as np
import string
import re


#read the dictionary words into a Pandas dataframe
dict_df = pandas.read_csv("../data/LIWC2015-dictionaries.csv", encoding='utf-8', header=3)


lyrics_df = pandas.read_csv("../data/bbtop15-lyrics-tokenized.csv",converters={'tokens_lower':literal_eval, 'tokens_lower_clean':literal_eval, "tokens_lower_clean_stopfree_stem": literal_eval } )

#drop rows where the text is missing.
lyrics_df  = lyrics_df.dropna(subset=['lyrics'])

lyrics_df

# Join stems back into list
lyrics_df['lyrics_stemmed'] = df['tokens_lower_clean_stopfree_stem'].apply(lambda x: " ".join(x))
df['lyrics_stemmed'][0]
# Out:
#       track_id                          track  \
# 0            0                    Me So Horny
# 1            1                    Bust A Move
# 2            2                Smooth Operator
# 3            3                    Cha Cha Cha
# 4            4                   I Go To Work
# 5            5                 New Jack Swing
# 6            6         They Put Me In The Mix
# 7            7                  Just A Friend
# 8            8              It's Funky Enough
# 9            9                Somebody For Me
# 10          10                      Say No Go
# 11          11                  Lethal Weapon
# 12          12                 Glamorous Life
# 13          13                     The Rhythm
# 14          14                 You Must Learn
# 15          17         Steppin' Into The A.M.
# 16          18                          Pause
# 17          19                Fight The Power
# 18          20                        Beepers
# 19          21               Express Yourself
# 20          22              So Wat Cha Sayin'
# 21          23     I Think I Can Beat Mike T.
# 22          29                         F.B.I.
# 23          34                    Turn It Out
# 24          35             Principal's Office
# 25          39                     Expression
# 26          42             I Get The Job Done
# 27          43                          Buddy
# 28          47      Welcome To The Terrordome
# 29          48                   Ladies First
# ...        ...                            ...
# 2287      2800             Key To The Streets
# 2288      2801  Juju On That Beat (TZ Anthem)
# 2289      2802                       All Eyez
# 2290      2803                     Bad Things
# 2291      2804                      Fake Love
# 2292      2805                       Sneakin'
# 2293      2806                       No Heart
# 2294      2807                          Litty
# 2295      2808                          Froze
# 2296      2809                       Offended
# 2297      2810           Two Birds, One Stone
# 2298      2811                 On The Regular
# 2299      2812                   Used To This
# 2300      2813                    Bounce Back
# 2301      2814                 Bad And Boujee
# 2302      2815              We The People....
# 2303      2816                 What They Want
# 2304      2818                     Greenlight
# 2305      2819                  Black Barbies
# 2306      2821                 False Prophets
# 2307      2822                       Immortal
# 2308      2823                      Neighbors
# 2309      2824                         Change
# 2310      2825                She's Mine Pt.1
# 2311      2826        For Whom The Bell Tolls
# 2312      2827                Ville Mentality
# 2313      2828               4 Your Eyez Only
# 2314      2829                 Foldin Clothes
# 2315      2830               She's Mine Pt. 2
# 2316      2831                 Everybody Dies
#
#                                               artist artist_gender  \
# 0                                    The 2 Live Crew          Male
# 1                                         Young M.C.          Male
# 2                                     Big Daddy Kane          Male
# 3                                            MC Lyte        Female
# 4                                       Kool Moe Dee          Male
# 5                                    Wreckx-N-Effect          Male
# 6                                        M.C. Hammer          Male
# 7                                         Biz Markie          Male
# 8                                         The D.O.C.          Male
# 9                                 Heavy D & The Boyz          Male
# 10                                        De La Soul          Male
# 11                                             Ice-T          Male
# 12                                            Cool C          Male
# 13                                             Kwame          Male
# 14                           Boogie Down Productions          Male
# 15                                          3rd Bass          Male
# 16                                        Run-D.M.C.          Male
# 17                                      Public Enemy          Male
# 18                                     Sir Mix-A-Lot          Male
# 19                                            N.W.A.          Male
# 20                                              EPMD          Male
# 2309  2016-12-31  2016  \n\n[Intro]\nMy intuition is telling me there'...
# 2310  2016-12-31  2016  \n\n[Intro]\nI never felt so alive\nI never fe...
# 2311  2016-12-31  2016  \n\n[Intro]\nI see the, I see the—\nI see the,...
# 2312  2016-12-31  2016  \n\n[Hook]\nHow long can I survive with this m...
# 2313  2016-12-31  2016  \n\n[Intro: J. Cole]\nYeah (For your eyes)\nFo...
# 2314  2016-12-31  2016  \n\n[Hook]\nI wanna fold clothes for you\nI wa...
# 2315  2016-12-31  2016  \n\n[Intro]\nCatch me, don't you\nCatch me, do...
# 2316  2016-12-31  2016  \n\n[Intro]\nYeah, we back\nBack in Mohammed c...
#
#                                            lyrics_clean  \
# 0     \n\n\n"Whatll we get for 10 dollars?"\n"Every ...
# 1     \n\n\nBust it\n\n\nThis heres a jam for all th...
# 2     \n\n\nWell excuse me, take a few minutes, to m...
# 3     \n\n\n\nYou can cha-cha-cha to this Mardis Gra...
# 4     \n\n\nI go to work like a doctor\nWhen I rock ...
# 5     \n\nYo Wreckx-N-Effect\nIn full effect!\n("Wor...
# 6     \n\n\nYo! My Lone Mixer\nYou ready?\nBust it!\...
# 7     \n\n\nHave you ever met a girl that you tried ...
# 8     \n\n\nYall ready for this\nRastafara Sonna Mad...
# 9     \n\nOh yeah..\n\nLove somebo-dy...\n\n(Al B. S...
# 10    \n\nPOS:\nNow lets get right on down to the sk...
# 11    \n\n\nE-V-I-L E and Ice-T are on a jack move\n...
# 12    \n\n(Samples)\nOh Ohhhhhh\nYou got it!\nThe gl...
# 13    \n\nLadies and gentlemen\nThe Kit-Kat Club is ...
# 14    \n\n\nJust like I told you, you must learn\n\n...
# 15    \n\n*sound of clocks ringing*\n\n\nReady in th...
# 16    \n\nArtist: Run-D.M.C\nAlbum:  Back From Hell\...
# 17    \n\n\n\n\nYet our best trained, best educated,...
# 18    \n\nOperators voice:\n(Welcome to Sky Pager)\n...
# 19    \n\n\nDr. Dre: Yo, man, its a lot of brothers ...
# 20    \n\n\nThe employees of the year, yeah were bac...
# 21    \n\n\nHey...hey Leroy...Leroy\n>>Yeah\nDid you...
# 22    \n\nPeople of the world\nTheres a serious prob...
# 23    \n\n\nDo-doo-do-doo (Go! Go! Go! Go!)\nDo-doo-...
# 24    \n\n\nNow normally if I can help But I dont sp...
# 25    \n\nOh yeah, oh yeah\nYou know life is all abo...
# 26    \n\n Hey yo Teddy\n Yo\n I ran into a young la...
# 27    \n\n\nHello\n\nMeany, meany, meany, meany (Say...
# 28    \n\n\nI got so much trouble on my mind\nRefuse...
# 29    \n\n\nThe ladies will kick it, the rhyme that ...
# ...                                                 ...
# 2287  \n\n\n\n\nI got money way before the deal\nPut...
# 2288  \n\n\nDo that one dance baby\nThat, that one d...
# 2289  \n\n\n(Scott Storch)\nAll eyes on ya\nAsk you ...
# 2290  \n\n\nAm I out of my head?\nAm I out of my min...
# 2291  \n\n\nIve been down so long, it look like up t...
# 2292  \n\n\nThis is all Gods doing, man, you cant pl...
# 2293  \n\n\nYoung Savage, why you trappin so hard?\n...
# 2294  \n\n\nWoo! Im on my way to an island\nAnd Im p...
# 2295  \n\n\nIm a rockstar, smash my guitar\nDiamonds...
# 2296  \n\n\nMeek Milly, Jeffery, woah\n\n\nYeah, yea...
# 2297  \n\n\nYeah, more, yeah\n\n\nMore time with fam...
# 2298  \n\n\nSell a lot of dope\nDodge a lot of cases...
# 2299  \n\n\n(Zaytoven)\n\n\nMexicano, working like I...
# 2300  \n\n\nIf Young Metro dont trust you, Im gon sh...
# 2301  \n\n\nYou know, young rich niggas\nYou know so...
# 2302  \n\n\nWe dont believe you cause we the people\...
# 2303  \n\n\n\n\nThey let us in the rap game\nI swear...
# 2304  \n\n\nRed light, green light\nEverybody take a...
# 2305  \n\n\nMike Will Made It Nigga\nSremm Life\nBla...
# 2306  \n\n\nSomebody shoulda told me it would be lik...
# 2307  \n\n\nAwwwww...haha\n\n\nNow I was barely seve...
# 2308  \n\n\nI guess the neighbors think Im sellin do...
# 2309  \n\n\nMy intuition is telling me therell be be...
# 2310  \n\n\nI never felt so alive\nI never felt so a...
# 2311  \n\n\nI see the, I see the—\nI see the, I see ...
# 2312  \n\n\nHow long can I survive with this mentali...
# 2313  \n\n\nYeah (For your eyes)\nFor your eyes only...
# 2314  \n\n\nI wanna fold clothes for you\nI wanna ma...
# 2315  \n\n\nCatch me, dont you\nCatch me, dont you\n...
# 2316  \n\n\nYeah, we back\nBack in Mohammed crib, ni...
#
#                                                  tokens  \
# 0     ['"Whatll', 'we', 'get', 'for', '10', 'dollars...
# 1     ['Bust', 'it', 'This', 'heres', 'a', 'jam', 'f...
# 2     ['Well', 'excuse', 'me,', 'take', 'a', 'few', ...
# 3     ['You', 'can', 'cha-cha-cha', 'to', 'this', 'M...
# 4     ['I', 'go', 'to', 'work', 'like', 'a', 'doctor...
# 5     ['Yo', 'Wreckx-N-Effect', 'In', 'full', 'effec...
# 6     ['Yo!', 'My', 'Lone', 'Mixer', 'You', 'ready?'...
# 7     ['Have', 'you', 'ever', 'met', 'a', 'girl', 't...
# 8     ['Yall', 'ready', 'for', 'this', 'Rastafara', ...
# 9     ['Oh', 'yeah..', 'Love', 'somebo-dy...', '(Al'...
# 10    ['POS:', 'Now', 'lets', 'get', 'right', 'on', ...
# 11    ['E-V-I-L', 'E', 'and', 'Ice-T', 'are', 'on', ...
# 12    ['(Samples)', 'Oh', 'Ohhhhhh', 'You', 'got', '...
# 13    ['Ladies', 'and', 'gentlemen', 'The', 'Kit-Kat...
# 14    ['Just', 'like', 'I', 'told', 'you,', 'you', '...
# 15    ['*sound', 'of', 'clocks', 'ringing*', 'Ready'...
# 16    ['Artist:', 'Run-D.M.C', 'Album:', 'Back', 'Fr...
# 17    ['Yet', 'our', 'best', 'trained,', 'best', 'ed...
# 18    ['Operators', 'voice:', '(Welcome', 'to', 'Sky...
# 19    ['Dr.', 'Dre:', 'Yo,', 'man,', 'its', 'a', 'lo...
# 20    ['The', 'employees', 'of', 'the', 'year,', 'ye...
# 21    ['Hey...hey', 'Leroy...Leroy', '>>Yeah', 'Did'...
# 22    ['People', 'of', 'the', 'world', 'Theres', 'a'...
# 23    ['Do-doo-do-doo', '(Go!', 'Go!', 'Go!', 'Go!)'...
# 24    ['Now', 'normally', 'if', 'I', 'can', 'help', ...
# 25    ['Oh', 'yeah,', 'oh', 'yeah', 'You', 'know', '...
# 26    ['Hey', 'yo', 'Teddy', 'Yo', 'I', 'ran', 'into...
# 27    ['Hello', 'Meany,', 'meany,', 'meany,', 'meany...
# 28    ['I', 'got', 'so', 'much', 'trouble', 'on', 'm...
# 29    ['The', 'ladies', 'will', 'kick', 'it,', 'the'...
# ...                                                 ...
# 2287  ['I', 'got', 'money', 'way', 'before', 'the', ...
# 2288  ['Do', 'that', 'one', 'dance', 'baby', 'That,'...
# 2289  ['(Scott', 'Storch)', 'All', 'eyes', 'on', 'ya...
# 2290  ['Am', 'I', 'out', 'of', 'my', 'head?', 'Am', ...
# 2291  ['Ive', 'been', 'down', 'so', 'long,', 'it', '...
# 2292  ['This', 'is', 'all', 'Gods', 'doing,', 'man,'...
# 2293  ['Young', 'Savage,', 'why', 'you', 'trappin', ...
# 2294  ['Woo!', 'Im', 'on', 'my', 'way', 'to', 'an', ...
# 2295  ['Im', 'a', 'rockstar,', 'smash', 'my', 'guita...
# 2296  ['Meek', 'Milly,', 'Jeffery,', 'woah', 'Yeah,'...
# 2297  ['Yeah,', 'more,', 'yeah', 'More', 'time', 'wi...
# 2298  ['Sell', 'a', 'lot', 'of', 'dope', 'Dodge', 'a...
# 2299  ['(Zaytoven)', 'Mexicano,', 'working', 'like',...
# 2300  ['If', 'Young', 'Metro', 'dont', 'trust', 'you...
# 2301  ['You', 'know,', 'young', 'rich', 'niggas', 'Y...
# 2302  ['We', 'dont', 'believe', 'you', 'cause', 'we'...
# 2303  ['They', 'let', 'us', 'in', 'the', 'rap', 'gam...
# 2304  ['Red', 'light,', 'green', 'light', 'Everybody...
# 2305  ['Mike', 'Will', 'Made', 'It', 'Nigga', 'Sremm...
# 2306  ['Somebody', 'shoulda', 'told', 'me', 'it', 'w...
# 2307  ['Awwwww...haha', 'Now', 'I', 'was', 'barely',...
# 2308  ['I', 'guess', 'the', 'neighbors', 'think', 'I...
# 2309  ['My', 'intuition', 'is', 'telling', 'me', 'th...
# 2310  ['I', 'never', 'felt', 'so', 'alive', 'I', 'ne...
# 2311  ['I', 'see', 'the,', 'I', 'see', 'the—', 'I', ...
# 2312  ['How', 'long', 'can', 'I', 'survive', 'with',...
# 2313  ['Yeah', '(For', 'your', 'eyes)', 'For', 'your...
# 2314  ['I', 'wanna', 'fold', 'clothes', 'for', 'you'...
# 2315  ['Catch', 'me,', 'dont', 'you', 'Catch', 'me,'...
# 2316  ['Yeah,', 'we', 'back', 'Back', 'in', 'Mohamme...
#
#                                            tokens_lower  \
# 0     ["whatll, we, get, for, 10, dollars?", "every,...
# 1     [bust, it, this, heres, a, jam, for, all, the,...
# 2     [well, excuse, me,, take, a, few, minutes,, to...
# 3     [you, can, cha-cha-cha, to, this, mardis, gras...
# 4     [i, go, to, work, like, a, doctor, when, i, ro...
# 5     [yo, wreckx-n-effect, in, full, effect!, ("wor...
# 6     [yo!, my, lone, mixer, you, ready?, bust, it!,...
# 2312  [how, long, can, i, survive, with, this, menta...
# 2313  [yeah, for, your, eyes, for, your, eyes, only,...
# 2314  [i, wanna, fold, clothes, for, you, i, wanna, ...
# 2315  [catch, me, dont, you, catch, me, dont, you, c...
# 2316  [yeah, we, back, back, in, mohammed, crib, nig...
#
#                             tokens_lower_clean_stopfree  \
# 0     ['whatll', 'get', 'dollars', 'every', 'ting', ...
# 1     ['bust', 'heres', 'jam', 'fellas', 'tryin', 'l...
# 2     ['well', 'excuse', 'take', 'minutes', 'mellow'...
# 3     ['chachacha', 'mardis', 'gras', 'im', 'dopest'...
# 4     ['go', 'work', 'like', 'doctor', 'rock', 'mic'...
# 5     ['yo', 'wreckxneffect', 'full', 'effect', 'wor...
# 6     ['yo', 'lone', 'mixer', 'ready', 'bust', 'lone...
# 7     ['ever', 'met', 'girl', 'tried', 'date', 'year...
# 8     ['yall', 'ready', 'rastafara', 'sonna', 'madda...
# 9     ['oh', 'yeah', 'love', 'somebody', 'al', 'b', ...
# 10    ['pos', 'lets', 'get', 'right', 'skit', 'baby'...
# 11    ['evil', 'e', 'icet', 'jack', 'move', 'layin',...
# 12    ['samples', 'oh', 'ohhhhhh', 'got', 'glamorous...
# 13    ['ladies', 'gentlemen', 'kitkat', 'club', 'pro...
# 14    ['like', 'told', 'must', 'learn', 'calm', 'yet...
# 15    ['sound', 'clocks', 'ringing', 'ready', 'intro...
# 16    ['artist', 'rundmc', 'album', 'back', 'hell', ...
# 17    ['yet', 'best', 'trained', 'best', 'educated',...
# 18    ['operators', 'voice', 'welcome', 'sky', 'page...
# 19    ['dr', 'dre', 'yo', 'man', 'lot', 'brothers', ...
# 20    ['employees', 'year', 'yeah', 'back', 'work', ...
# 21    ['heyhey', 'leroyleroy', 'yeah', 'hear', 'boy'...
# 22    ['people', 'world', 'theres', 'serious', 'prob...
# 23    ['dodoododoo', 'go', 'go', 'go', 'go', 'dodood...
# 24    ['normally', 'help', 'dont', 'spend', 'lot', '...
# 25    ['oh', 'yeah', 'oh', 'yeah', 'know', 'life', '...
# 26    ['hey', 'yo', 'teddy', 'yo', 'ran', 'young', '...
# 27    ['hello', 'meany', 'meany', 'meany', 'meany', ...
# 28    ['got', 'much', 'trouble', 'mind', 'refuse', '...
# 29    ['ladies', 'kick', 'rhyme', 'wicked', 'dont', ...
# ...                                                 ...
# 2287  ['got', 'money', 'way', 'deal', 'put', 'bitche...
# 2288  ['one', 'dance', 'baby', 'one', 'dance', 'yeah...
# 2289  ['scott', 'storch', 'eyes', 'ya', 'ask', 'week...
# 2290  ['head', 'mind', 'knew', 'bad', 'things', 'lik...
# 2291  ['ive', 'long', 'look', 'like', 'look', 'got',...
# 2292  ['gods', 'man', 'cant', 'plan', 'devils', 'det...
# 2293  ['young', 'savage', 'trappin', 'hard', 'niggas...
# 2294  ['woo', 'im', 'way', 'island', 'im', 'popping'...
# 2295  ['im', 'rockstar', 'smash', 'guitar', 'diamond...
# 2296  ['meek', 'milly', 'jeffery', 'woah', 'yeah', '...
# 2297  ['yeah', 'yeah', 'time', 'family', 'friends', ...
# 2298  ['sell', 'lot', 'dope', 'dodge', 'lot', 'cases...
# 2299  ['zaytoven', 'mexicano', 'working', 'like', 'i...
# 2300  ['young', 'metro', 'dont', 'trust', 'im', 'gon...
# 2301  ['know', 'young', 'rich', 'niggas', 'know', 'a...
# 2302  ['dont', 'believe', 'cause', 'people', 'still'...
# 2303  ['let', 'us', 'rap', 'game', 'swear', 'let', '...
# 2304  ['red', 'light', 'green', 'light', 'everybody'...
# 2305  ['mike', 'made', 'nigga', 'sremm', 'life', 'bl...
# 2306  ['somebody', 'shoulda', 'told', 'would', 'like...
# 2307  ['awwwwwhaha', 'barely', 'seventeen', 'pocket'...
# 2308  ['guess', 'neighbors', 'think', 'im', 'sellin'...
# 2309  ['intuition', 'telling', 'therell', 'better', ...
# 2310  ['never', 'felt', 'alive', 'never', 'felt', 'a...
# 2311  ['see', 'see', 'the—', 'see', 'see', 'the—', '...
# 2312  ['long', 'survive', 'mentality', 'long', 'surv...
# 2313  ['yeah', 'eyes', 'eyes', 'eyes', 'eyes', 'eyes...
# 2314  ['wanna', 'fold', 'clothes', 'wanna', 'make', ...
# 2315  ['catch', 'dont', 'catch', 'dont', 'catch', 'i...
# 2316  ['yeah', 'back', 'back', 'mohammed', 'crib', '...
#
#                        tokens_lower_clean_stopfree_stem
# 0     [whatll, get, dollar, everi, ting, want, every...
# 1     [bust, here, jam, fella, tryin, ladi, tell, us...
# 2     [well, excus, take, minut, mellow, big, daddi,...
# 3     [chachacha, mardi, gras, im, dopest, femal, yo...
# 4     [go, work, like, doctor, rock, mic, got, like,...
# 5     [yo, wreckxneffect, full, effect, word, know, ...
# 6     [yo, lone, mixer, readi, bust, lone, mixer, sa...
# 7     [ever, met, girl, tri, date, year, make, love,...
# 8     [yall, readi, rastafara, sonna, madda, fa, dro...
# 9     [oh, yeah, love, somebodi, al, b, sure, harmon...
# 10    [pos, let, get, right, skit, babi, brought, wo...
# 11    [evil, e, icet, jack, move, layin, dope, groov...
# 12    [sampl, oh, ohhhhhh, got, glamor, life, go, go...
# 13    [ladi, gentlemen, kitkat, club, proud, present...
# 14    [like, told, must, learn, calm, yet, wild, sty...
# 15    [sound, clock, ring, readi, intro, cue, serchl...
# 16    [artist, rundmc, album, back, hell, song, paus...
# 17    [yet, best, train, best, educ, best, equip, be...
# 18    [oper, voic, welcom, sky, pager, sound, beeper...
# 19    [dr, dre, yo, man, lot, brother, flakin, perpe...
# 20    [employe, year, yeah, back, work, took, time, ...
# 21    [heyhey, leroyleroy, yeah, hear, boy, mike, ty...
# 22    [peopl, world, there, serious, problem, call, ...
# 23    [dodoododoo, go, go, go, go, dodoododooohdo, g...
# 24    [normal, help, dont, spend, lot, time, princip...
# 25    [oh, yeah, oh, yeah, know, life, express, live...
# 26    [hey, yo, teddi, yo, ran, young, ladi, maliya,...
# 27    [hello, meani, meani, meani, meani, say, meani...
# 28    [got, much, troubl, mind, refus, lose, here, t...
# 29    [ladi, kick, rhyme, wick, dont, know, pros, ge...
# ...                                                 ...
# 2287  [got, money, way, deal, put, bitch, new, pair,...
# 2288  [one, danc, babi, one, danc, yeah, oh, dont, k...
# 2289  [scott, storch, eye, ya, ask, week, workin, al...
# 2290  [head, mind, knew, bad, thing, like, dont, thi...
# 2291  [ive, long, look, like, look, got, fake, peopl...
# 2292  [god, man, cant, plan, devil, detail, im, sata...
# 2293  [young, savag, trappin, hard, nigga, cappin, h...
# 2294  [woo, im, way, island, im, pop, shit, pilot, f...
# 2295  [im, rockstar, smash, guitar, diamond, fist, a...
# 2296  [meek, milli, jefferi, woah, yeah, yeah, fuck,...
# 2297  [yeah, yeah, time, famili, friend, life, time,...
# 2298  [sell, lot, dope, dodg, lot, case, stickin, ba...
# 2299  [zaytoven, mexicano, work, like, im, mexicano,...
# 2300  [young, metro, dont, trust, im, gon, shoot, la...
# 2301  [know, young, rich, nigga, know, aint, realli,...
# 2302  [dont, believ, caus, peopl, still, rear, ayo, ...
# 2303  [let, us, rap, game, swear, let, motherfuck, r...
# 2304  [red, light, green, light, everybodi, take, sh...
# 2305  [mike, made, nigga, sremm, life, black, barbi,...
# 2306  [somebodi, shoulda, told, would, like, like, l...
# 2307  [awwwwwhaha, bare, seventeen, pocket, full, ho...
# 2308  [guess, neighbor, think, im, sellin, dope, sel...
# 2309  [intuit, tell, therel, better, day, yeah, intu...
# 2310  [never, felt, aliv, never, felt, aliv, never, ...
# 2311  [see, see, the—, see, see, the—, see, rain, po...
# 2312  [long, surviv, mental, long, surviv, mental, t...
# 2313  [yeah, eye, eye, eye, eye, eye, eye, eye, eye,...
# 2314  [wanna, fold, cloth, wanna, make, feel, good, ...
# 2315  [catch, dont, catch, dont, catch, ive, fallen,...
# 2316  [yeah, back, back, moham, crib, nigga, top, fl...
#
# [2317 rows x 13 columns]

# %% [markdown]
# # Background on the Corpus
#
# We composed our corpus of rap lyrics by first making a list of all the rap songs that have appeared on the Billboard Hot Rap Songs list from 1989-2016 (http://www.billboard.com/charts/rap-song).
#
# To get the lyrics, we wrote a script that scraped 2317 lyrics from the well-established lyrics site Rap Genius(https://genius.com). That is about 81% of all the songs that appears on the list during the specified time period. The figure bellow illustrated how the lyrics are distributed across time. Our corpus also necessitated computational cleaning in removing variables such as uppercase letters, punctuation, etc..
#
# This data collection functions as an appropriate selection for our investigation as we are interested in tracking how **recent** manifestations of hip-hop and rap have evolved as (A) a product of being in the **mainstream** (hence why we selected Billboard Hot Rap Songs), and (B) through modern sociological conditions of the time (we wanted to study influences after 1994, where hip-hop and rap historically has entered the mainstream).

# %%
grouped_year = lyrics_df.groupby("year")
grouped_year['lyrics'].count().plot(kind = 'bar')
plt.show()


plt.figure(figsize=(6, 8))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False) 
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-23a5b0b038d0> in <module>()
# ----> 1 grouped_year = lyrics_df.groupby("year")
#       2 grouped_year['lyrics'].count().plot(kind = 'bar')
#       3 plt.show()
#       4
#       5
#
# NameError: name 'lyrics_df' is not defined

# %% [markdown]
# # I. Topic Modeling of Notable Themes
#
# In this section, we are interested in noting some of what computational analysis will prescribe as the most notable themes in recent, mainstream rap and hip-hop. We decide to define the corpus with six topics to get a distinct range of topics, and to hopefully account for unusual phrasing, slang, and errors in tokenizing the unique syntax of rap and hip-hop lyrics. In this section, we are partially looking to validate previous research that suggests partying, women, violence/gangs, and status were notable themes in the foundations of rap and hip-hop before 1994.

# %%
####Adopted From: 
#Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Lars Buitinck
#         Chyi-Kwei Yau <chyikwei.yau@gmail.com>
# License: BSD 3 clause

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

n_samples = 2317
n_topics = 6
n_top_words = 80

##This is a function to print out the top words for each topic in a pretty way.
#Don't worry too much about understanding every line of this code.
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.80, min_df=50,
                                max_features=None,
                                stop_words='english'
                                )

tf = tf_vectorizer.fit_transform(df.lyrics_clean)
# Out:
# Extracting tf features for LDA...

# %%
print("Fitting LDA models with tf features, "
      "n_samples=%d and n_topics=%d..."
      % (n_samples, n_topics))

#define the lda function, with desired options
#Check the documentation, linked above, to look through the options
lda = LatentDirichletAllocation(n_topics=n_topics, max_iter=20,
                                learning_method='online',
                                learning_offset=80.,
                                total_samples=n_samples,
                                random_state=0)
#fit the model
lda.fit(tf)
# Out:
# Fitting LDA models with tf features, n_samples=2317 and n_topics=6...
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=80.0,
#              max_doc_update_iter=100, max_iter=20, mean_change_tol=0.001,
#              n_jobs=1, n_topics=6, perp_tol=0.1, random_state=0,
#              topic_word_prior=None, total_samples=2317, verbose=0)

# %%
print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topics in LDA model:
#
# Topic #0:
# love night good new long used need city thing ll day girl feeling youre let right boy mean better dont don old heart live make left going want time just tell mind little really baby feel whats things cause told women yeah ya hit talk aint hate ive gon lot em home gone world thats friends believe girls round looking body wrong fuck hoes hard said leave game oh seen wont young coming real open bout couple think man niggas
#
# Topic #1:
# work look gonna doing girl roll don little gotta let hard ya baby cause aint god black heard come drink damn girls smoke man dont bring youre right gon best whats everybody car wanna ll club thing play say bad thats friends good body left make believe live ball boy care party better oh time day said ain pay long home hate free start walk need really want just em hot song weed round talking beat probably gone theres feeling
#
# Topic #2:
# money just nigga young bitch dope night gon hold em hoes day time party girl ho hey cash ball aint yeah way club better niggas cause throw lookin make say think tryna song bitches fuck dont good gold getting let damn long hit bad shit round thats everybody wanna goin man high ya city ass don big tell looking couple house roll play ride look bout white free right face til mind came hell need real hood told ain come
#
# Topic #3:
# dont ass nigga thats shit really make watch need bitch fuck aint niggas man rich big just bitches real ima boy wanna em say fuckin yeah pussy look better ill hit cause gon way black want tell drop things talkin girl believe new catch run turn time walk care ya yo yall bout girls feel think white heard told lookin come money pay night came bad okay lil tryna god young love head oh youre gettin gotta wont gold hate
#
# Topic #4:
# baby just oh girl yeah cause make dont aint way wanna let want tell need come youre time say right feel lets life real shit ill blow crazy good think gotta slow ya gone imma love did em bad fuck body world look tryna money home going change don man thats wont gon turn fly high head told hold ive bout little day god mean fucking nigga said thing uh coming light drop mind play yall night eyes hit theres
#
# Topic #5:
# niggas nigga fuck bitch aint shit yeah said dont just money cause man bout right em want bitches thats gotta tell new say talk came pussy yall boy bad come dick did let make hit look talkin life talking uh ain pull time stop gon don big nothin live stay pop ride die wanna going hard hoes game real friends straight leave gettin hood tryna girls need fucking check seen million ive run lot good ho ya really damn party

# %%
df_w_topics['word_count'] = df_w_topics['tokens_lower_clean'].apply(lambda x: len(str(x).split()))

# %%
df_w_topics['0_wc'] = df_w_topics[0] * df_w_topics['word_count']

# %%
topic_columns = range(0,6)

# %%
col_list = []
for num in topic_columns:
    col = "%d_wc" % num
    col_list.append(col)
    #Solution
    df_w_topics[col] = df_w_topics[num] * df_w_topics['word_count']

# %%
grouped_year = df_w_topics.groupby('year')
fig3 = plt.figure()
chrt = 0
for e in col_list:
    chrt += 1 
    ax2 = fig3.add_subplot(2,3, chrt)
    (grouped_year[e].sum()/grouped_year['word_count'].sum()).plot(kind='line', title=e)
    
fig3.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-238-84b49c1d7cdf> in <module>()
#       5     chrt += 1
#       6     ax2 = fig3.add_subplot(2,3, chrt)
# ----> 7     (grouped_year[e].sum()/grouped_year['word_count'].sum()).plot(kind='line', title=e)
#       8
#       9 fig3.tight_layout()
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3564                            colormap=colormap, table=table, yerr=yerr,
#    3565                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3566                            **kwds)
#    3567     __call__.__doc__ = plot_series.__doc__
#    3568
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2643                  yerr=yerr, xerr=xerr,
#    2644                  label=label, secondary_y=secondary_y,
# -> 2645                  **kwds)
#    2646
#    2647
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2439         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2440
# -> 2441     plot_obj.generate()
#    2442     plot_obj.draw()
#    2443     return plot_obj.result
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in generate(self)
#    1024     def generate(self):
#    1025         self._args_adjust()
# -> 1026         self._compute_plot_data()
#    1027         self._setup_subplots()
#    1028         self._make_plot()
#
# //anaconda/lib/python3.5/site-packages/pandas/tools/plotting.py in _compute_plot_data(self)
#    1133         if is_empty:
#    1134             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1135                             'plot'.format(numeric_data.__class__.__name__))
#    1136
#    1137         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %% [markdown]
# ## Analysis on Topic Modeling
#
# Our interpretation of the six topics we found evidence for include:
# - Topic 0: "Sex and Love"
# - Topic 1: "Social Gatherings and Celebration"
# - Topic 2: "Appeal for Status"
# - Topic 3: "Assertion of Power"
# - Topic 4: "Coquettish Rhetoric"
# - Topic 5: "Gangs, Ghettos, and Violence".
#
# These topics have shifted slightly since the first time we attempted this same analysis. This is because we cleaned up the corpus by stemming the lyrics, removing stop words/digits/etc., and using a tf-idf vectorizer.
#
# Insofar as verifying our previous research into rap and hip-hop lyrical themes, this computational method supports the suggestions taken from the "Hip-Hop Evolution" documentary that suggest that much of the lyrical inspiration has come from  partying, women, and the reality of black, urban neighborhoods. If our hypothesis (that rap and hip-hop have reflected less meaningful content as it is increasingly commercialized) is correct, we should see increases in lyrical reference to all of the topics over time, except for Topic 5. We interpret Topic 5 to be a product of the reminiscence of "gangster rap". According to the "Evolution of Hip-Hop", gangster rap was a style of rap/hip-hop that had its origins in California in the late 80s and was popularized by groups such as Ice-T, Dr. Dre, and NWA.
#
# We would like to take this analysis a step further my examining specific topics. This leads us to Part II of our project.

# %% [markdown]
# # II. Examining Specific Topics Through LIWC
#
# In this section, we will be examining some of the most notable themes that surfaced through our previous research and topic modeling. Though we went through several prototypes in how to best do this investigation, we decided that we will be relying on LIWC dictionaries.
#
# As a result of this reliance, the themes that we will be looking into are products of the LIWC preexisting categories. The relevant categories we found include: money, power, sex, anger, leisure, swear words, risk, and insight. We choose these categories by looking at overlaps of the words cited in topic modeling and in the LIWC dictionary index. We acknowledge that dictionary methods and their subsequent interpretation carry some inherent biases.

# %%
## Update columns of the dictionary df

new_columns =['Function1', 'Function2', 'Function3', 'Function4', 'Pronoun', 'Ppron', 'I', 'We', 'You', 'SheHe', 'They', 'Ipron', 'Article', 'Prep', 'Auxverb', 'Adverb', 'Conj', 'Negate', 'Verb1', 'Verb2', 'Verb3', 'Verb4', 'Verb5', 'Verb6', 'Verb7', 'Adj1', 'Adj2', 'Adj3', 'Adj4', 'Adj5', 'Compare', 'Unnamed: 31', 'Unnamed: 32', 'Interrog', 'Number', 'Quant', 'Affect', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Posemo1', 'Posemo2', 'Posemo3', 'Posemo4', 'Posemo5', 'Negemo1', 'Negemo2', 'Negemo3', 'Negemo4', 'Negemo5', 'Anx', 'Anger1', 'Anger2', 'Sad', 'Social', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Family', 'Friend', 'Female', 'Male', 'CogProc', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Insight1', 'Insight2', 'Cause', 'Discrep', 'Tentat', 'Unnamed: 80', 'Certain', 'Differ', 'Percent', 'Unnamed: 84', 'Unnamed: 85', 'See', 'Hear', 'Feel', 'Bio', 'Unnamed: 90', 'Unnamed: 91', 'Unnamed: 92', 'Unnamed: 93', 'Body1', 'Body2', 'Health1', 'Health2', 'Sexual', 'Ingest1', 'Ingest2', 'Drives1', 'Drives2', 'Drives3', 'Drives4', 
'Drives5', 
'Drives6', 
'Drives7', 
'Drives8', 
'Affiliation1', 
'Affiliation2', 
'Achieve1', 
'Achieve12', 
'Power1',
 'Power2',  h
'Power3', 
'Power4', 
'Reward', 'Risk', 
'FocusPast', 
'Unnamed: 120',
 'Unnamed: 121', 
'FocusPresent', 
'Unnamed: 123', 
'Unnamed: 124', 
'FocusFuture', 
'Relativ', 
'Unnamed: 127', 
'Unnamed: 128', 
'Unnamed: 129', 
'Unnamed: 130', 
'Unnamed: 131', 
'Unnamed: 132', 
'Motion', 
'Unnamed: 134', 
'Unnamed: 135', 
'Space', 
'Unnamed: 137',
 'Unnamed: 138',
 'Time', 
'Unnamed: 140', 
'Work1', 
'Work2', 
'Work13', 
'Leisure1', 
'Leisure2', 
'Home', 
'Money1', 
'Money2', 
'Relig', 
'Unnamed: 150', 
'Death', 
'Informal1', 
'Informal2', 
'Informa3', 
'Swear', 
'Netspeak1', 
'Netspeak2', 
'Assent', 
'Nonflu', 
'Filler']

# %%
new_columns = [column.lower() for column in new_columns]
dict_df.columns = new_columns

# %%
#Function that return the dictionary that i want to investigate
def get_dict(df, label):
    df_dict =  df[lambda df: [column for column in df.columns if re.match(label + "*", column)]]
    words = []
    cols = df_dict.columns
    for col in cols:
        words += df_dict[col].tolist()
        
    ##Remove star
    return [word for word in words if str(word) != "nan"]

# %%
#dict_df[lambda df: [column for column in df.columns if re.match(r"function*", column)]]

money_dict = get_dict(dict_df, "money")

# %%
lyrics_df['token_count'] = lyrics_df['tokens_lower_clean'].apply(lambda x: len(x))

# %%
#creating dictionary counts

def dict_count(tokens, dictionary):
    count = 0
    for token in tokens:
        for word in dictionary: 
            if word[-1] =='*':
                search_string=word[0:-1]
                if re.match(search_string, token):
                    count += 1
                    #print(token)
                    #print(word)
            else:
                if word == token:
                    count += 1
                    #print(token)
                    #print(word)
    return count

# %% [markdown]
#  ## Investigation on Money

# %%
lyrics_df['money_count'] = lyrics_df['tokens_lower_clean'].apply(lambda x: dict_count(x, money_dict))

# %%
lyrics_df['money_ratio'] = lyrics_df['money_count'] / lyrics_df['token_count']

# %%
groupedby_year = lyrics_df.groupby('year')

# %%
groupedby_year['money_ratio'].mean().plot(kind='line')
plt.show()

# %% [markdown]
# ## Analysis on Money:
#
# As a general trend, it is clear that money has become a more popularized lyric topic over time. Though we can only speculate, our guess is that this is the consequence of rap and hip-hop entering the mainstream. We believe that by entering the mainstreams, rap and hip-hop artists reflect their reality in making and having more money and increasingly commercializing their products.
#
# ### A Closer Loor: Speculating on Sociological/Economic Influences
#
# Some of the interesting points in this graph include: the dips of 2003, 2011, and 2013 and the peaks of 2010, 2012, and 2015.
#
# In researching possible mechanisms that may have influenced the first dramatic dip in 2003, we found that 2002 and 2003 saw dramatic increases in poverty and unemployment rates. Poverty increase 0.4% each year: 11.7% to 12.1% in 2002, and 12.5% from 12.1% in 2003 (Schuelke, 2003). This notable increase accounts for the 2.3 million indivduals that fell into poverty during this two year period (CNN & Reuters, 2004). We hypothesizes that this economic consideration had exasterbated effects in poor, urban neighborhoods-- which have been the cultural origins of rap and hip-hop. This economic trend has leds us to believe that high poverty and unemployment rates do have an effect on the rap and hip-hop community.
#
# In considering the spike in 2010, we believe the high reference to money may be attributed to a bounceback from the 2008 recession. On September of 2010, the National Bureau of Economic Research stated that the US had offficially left the recession in June of 2009, as the GDP had recovered to 70% of the pre-recession level (onthisday.com). We speculate that this economic trend may have had sparked inspiration for consumerist behavior and reference.
#
# This increase is sharply contrasted with a dip in 2011. In researching some of the possible explanations, we found that in May of 2011, the US Department of Labor cited that alothough more and more jobs were being created, there remained many regions in which unemployment had continued to grow. In fact, unemployment rates plateaued at 9% for most of the year. It is possible that this economic concern fueled what was to come later in the year, as in September the protests known as Occupy Wall Street emerged throughout the nation. As individuals began to protest the increasing wage gap between the top 1% and the middle class, it is likely that many musical artists may have paused their references to money and wealth accumulation.
#
# The spike in 2012 introduces another interesting pivot as it completley counters the 2011 drop. We speculate that this increase in lyrical reference to money could have been a product of economic stabilization, as unemployment rates steadily decreased. We also hypothesize that it could have had relation to Obama's reelected, as his candidcacy stood as a powerful testimate of the strength and success to many black American constituents.
#
# In 2013 we see another stark decrease, which we speculate could have been a musical response to the Black Lives Matter (BLM) movement. BLM started in the summer of 2013, and we proposed that it may have inspired a lyrical shift for some of the rap community to start a musical discussion of race and discrimination.

# %% [markdown]
#  ## Investigation on Power

# %%
power_dict = get_dict(dict_df, "power")

# %%
lyrics_df['power_count'] = lyrics_df['tokens_lower_clean'].apply(lambda x: dict_count(x, power_dict))

# %%
lyrics_df['power_ratio'] = lyrics_df['power_count'] / lyrics_df['token_count']

# %%
groupedby_year = lyrics_df.groupby('year')

# %%
groupedby_year['power_ratio'].mean().plot(kind='line')
plt.show()

plt.figure(figsize=(12, 14))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False) 
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()

# %% [markdown]
# ## Analysis on Power:
#
# It is first worth acknowledging that the relevance of words associated with power is strikingly higher then those associated with money (power ranges from 0.022 - 0.032, money ranges from 0.004 - 0.011). Beyond that, as a general trend, power has keep a relatively stable general progression, though this graph clearly indicates notable peaks and valleys. We find it interesting that lyrical reference to rap has flucuated with such steep slopes in the past twenty-five years, and even moreso that power as a lyrical topic seems to be rarely affected in its introduction to the mainstream. We interpret the spike in the early 1990s to be a consequence of the emergence and popularization of "gangster rap". This graph seems to contridict our hypothesis, as we believed that reference to "gangs, ghettos, and violence" would decrease overtime, and that subsequently so would assertions of power. Our surprise can be partially nullified in that it is possible that the LIWC dictionary of power is measuring references to power that exclude or are not exclusive to the words found in the "gangs, ghettos, and violence" topic modeling category.
#
#
# ### A Closer Loor: Speculating on Sociological Influences
#
# Some of the interesting trends in this graph that we would like to discuss include: the dips of 2002/2003 and 2008 as well as the peaks of 1997 and 2001.
#
#
# In researching possible mechanisms that may have influenced the first dramatic peak in 1997, we speulated that assertions of power may have been affected by Bill Clinton's welfare reform intiative that ended Aid to Families with Dependent Children (AFDC) and started Temporary Assistance to Needy Families (TANF) in 1996. Both of these policies were and are regarded as "welfare" by the genernal public, but the different between the two is that TANF establishes much stronger work-requirements, strickter limitations to aid, revoked welfare as an entitlement, and harbors racist,  heteronormative, and discriminative marital values (Graaf and Ratliff, 2017). This is seen in three of the four goals of TANF as they draw reference to a specific and idealized family formation, included in their the aims to: (A) "end of dependence of needy parents by promoting job preparation, work, and marriage"; (B) "prevent and reduce the incidence of out of wedlock pregnancies and establish annual numerical goals for preventing and reducing those pregnancies"; and (3) "encourage the formation and maintaitenance of two parent families" (Graaf and Ratliff, 2017). Scholars suggests that such pointed goals were inherently racist and clasist as they specifically targeted single-mothers in impoverished communities (Graaf and Ratliff, 2017). We speculate that this policy shift could have inspired increase lyrical reference to power as a method of addressing the cultural reprecussions of TANF, considering that the policy had dramatic influences on low-income communities of where rap and hip-hop was coming from.
#
#
# This trend of an increased reference of power is sharply contrasted with a dramatic dip in 2002 and 2003. In researching some of the possible explanations, we speculate that this could have been a lyrical responce to the desolation that encompassed the nation after the 9/11 terrorist attacks in 2001. Immediately after the attacks, George W. Bush declared the "War on Terror" and in 2003 US invaded Iraq (Roberts, 2002). We speculate that such actions could have impacted mainstream culture of the time, as much of American was uncertained and scared of the potential implications of the war. Furthermore, after the attack, American cultural percetion saw increased rates of racism and discrimination, which we speculate may have additionally discouraged assertions of power and increased fear for all demographic (Lichtblau, 2016).
#
#
# Furthermore, we speculate that the deep decline of lyrical reference to power in 2008 may have be attributed to the stock market crash as a product of the housing crisis. The stock market crash occurred on September 29, 2008 as the Dow Jones Industrial Average fell 777.68 points in intra-day trading, which was the largest point drop in history (Amadeo, 2017). It had permeating effects through the US and world economy, and we speculate lyrical content may have responded to this panic with decrease reference in assertion of power. Considering that there was lots of panic-- people were loosing homes, jobs, and life-savings-- we believe that the broad reprecussion of the market crash would have caused musical artists in the mainstream to acknowledge the struggling country by tailoring their lyrics in reducing assertions of power.
#
# In 2013 we see another, contrasting and stark increase in reference to power. Here we speculate that this could have been another lyrical response to the Black Lives Matter (BLM) movement. We believe that the LIWC dictionary would log words that are associated with the BLM movement as related to power considering that much of the movement was centered around empowering rhetoric. For example the BLM website states that their ultimate goal is, "working to (re)build the Black liberation movement." The website cites the movement's foundation as a responce to George Zimmerman's acquittal in 2013 after the death of Trayvon Martin, and that since then they have since made efforts to advertise the "experiences of Black people in this country who actively resist our dehumanization... #BlackLivesMatter is a call to action and a response to the virulent anti-Black racism that permeates our society. Black Lives Matter is a unique contribution that goes beyond extrajudicial killings of Black people by police and vigilantes" (Cullors, Garza, & Tometi, n.d.).
#
# We believe that such a notable and permeating movement must have had influence on the lyrical themes of the times. Futhermore, our speculation about the relation of rap lyrics and BLM movement is cooberating in our previous analysis of "money". We previously proposed that when the BLM started in 2013, the rap and hip-hop community shifted its lyrical focus from money to a a commentry on race and discrimination. The analysis on power works in accordance with this theory- though we acknowledge that we lack data to make any conlusive findings.

# %%
df['tokens_lower_clean_stopfree'] = df['tokens_lower_clean_stopfree'].apply(lambda x: ''.join([i for i in x if not i.isdigit()]))

# %%
from sklearn.feature_extraction.text import CountVectorizer

countvec = CountVectorizer()

sklearn_dtm = countvec.fit_transform(df.tokens_lower_clean_stopfree)

# %%
dtm_df = pandas.DataFrame(countvec.fit_transform(df.tokens_lower_clean_stopfree).toarray(), columns=countvec.get_feature_names(), index = df.index)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidfvec = TfidfVectorizer()
dtm_tfidf_df = pandas.DataFrame(tfidfvec.fit_transform(df.tokens_lower_clean_stopfree).toarray(), columns=tfidfvec.get_feature_names(), index = df.index)

# %%
print(dtm_tfidf_df.max().sort_values(ascending=False)[:20])
# Out:
# versace     0.982205
# wit         0.980303
# la          0.972252
# faded       0.964198
# mediocre    0.946053
# ew          0.938533
# trophy      0.937226
# wop         0.936658
# honest      0.936049
# errbody     0.935593
# hol         0.918527
# hangover    0.915177
# bounce      0.914007
# nae         0.913308
# ass         0.912367
# thun        0.909820
# bubble      0.908904
# ooh         0.908480
# country     0.907953
# whistle     0.905863
# dtype: float64

# %%
lyrics_df = pandas.read_csv("../data/bbtop15-lyrics-tokenized.csv",converters={'tokens_lower':literal_eval, 'tokens_lower_clean':literal_eval } )

df = df.dropna(subset=['lyrics'])
df_1997 = df.query(' 1996 > year > 1998')

#view the dataframe
df_1997
# Out:
# Empty DataFrame
# Columns: [track_id, track, artist, artist_gender, date, year, lyrics, lyrics_clean, tokens, tokens_lower, tokens_lower_clean, tokens_lower_clean_stopfree, tokens_lower_clean_stopfree_stem]
# Index: []

# %% [markdown]
#  ## Investigation of Sex

# %%
sex_dict = get_dict(dict_df, "sexual")

# %%
lyrics_df['sex_count'] = lyrics_df['tokens_lower_clean'].apply(lambda x: dict_count(x, sex_dict))

# %%
lyrics_df['sex_ratio'] = lyrics_df['sex_count'] / lyrics_df['token_count']

# %%
groupedby_year = lyrics_df.groupby('year')

# %%
groupedby_year['sex_ratio'].mean().plot(kind='line')
plt.show()


plt.figure(figsize=(12, 14))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False) 
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()

# %% [markdown]
# ## Analysis on Sex:
#
# As a general trend, sex has also become a more popularized lyric topic over time, though its relevance rates remain  lower then thoses calculated with association to "money" and "power". Again, though we can only speculate, we believe that this trend has occured due to rap and hip-hop entering the mainstream in the early 1990s. We believe that since then, lyrical topics have become increasingly commercialized and as the famous quip states, "sex sells".

# %% [markdown]
#  ## Investigation of Anger

# %%
anger_dict = get_dict(dict_df, "anger")

# %%
lyrics_df['anger_count'] = lyrics_df['tokens_lower_clean'].apply(lambda x: dict_count(x, anger_dict))

# %%
lyrics_df['anger_ratio'] = lyrics_df['anger_count'] / lyrics_df['token_count']

# %%
groupedby_year = lyrics_df.groupby('year')

# %%
groupedby_year['anger_ratio'].mean().plot(kind='line')
plt.show()


plt.figure(figsize=(12, 14))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False) 
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()

# %% [markdown]
# ## Analysis on Anger:
#
# As a general trend, anger seems to have manifested as a fairly popular lyrical theme, as its rates are comparable to the high reference of power. Another interesting similarity the anger graph has to the graph on power is that 1999 emerges as a peak for both graphs. Furthermore, that the relevance substantially decreases from 2002-2007 and then sharply increases after that is an intriguing pattern.

# %% [markdown]
#  ## Investigation of Leisure

# %%
leisure_dict = get_dict(dict_df, "leisure")

# %%
lyrics_df['leisure_count'] = lyrics_df['tokens_lower_clean'].apply(lambda x: dict_count(x, leisure_dict))

# %%
lyrics_df['leisure_ratio'] = lyrics_df['leisure_count'] / lyrics_df['token_count']

# %%
groupedby_year = lyrics_df.groupby('year')

# %%
groupedby_year['leisure_ratio'].mean().plot(kind='line')
plt.show()

plt.figure(figsize=(12, 14))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False) 
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()

# %% [markdown]
# ## Analysis on Leisure:
#
# As a general trend, leisure seems to have manifested as a fairly relevant lyrical theme, as its rates are comparably high in considering relevance scores. One interesting illustration is that leisure seems to have been highly referenced in the late 1980s but that lyrical evolution has render it increasingly less relevant in the past five years.

# %% [markdown]
#  ## Investigation of Swear Words

# %%
swear_dict = get_dict(dict_df, "swear")

# %%
lyrics_df['swear_count'] = lyrics_df['tokens_lower_clean'].apply(lambda x: dict_count(x, swear_dict))

# %%
lyrics_df['swear_ratio'] = lyrics_df['swear_count'] / lyrics_df['token_count']

# %%
groupedby_year = lyrics_df.groupby('year')

# %%
groupedby_year['swear_ratio'].mean().plot(kind='line')
plt.show()


plt.figure(figsize=(12, 14))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False) 
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()

# %% [markdown]
# ## Analysis on Swear Words:
#
# It is interesting to see that the use of swear worsds is following an almost linear increase in relevance. Furthermore, the range of relevance is fairly unusual in this graph compared to others as scores range from 0.005 - 0.04.

# %% [markdown]
#  ## Investigation of Risk

# %%
risk_dict = get_dict(dict_df, "risk")

# %%
lyrics_df['risk_count'] = lyrics_df['tokens_lower_clean'].apply(lambda x: dict_count(x, risk_dict))

# %%
lyrics_df['risk_ratio'] = lyrics_df['risk_count'] / lyrics_df['token_count']

# %%
groupedby_year = lyrics_df.groupby('year')

# %%
groupedby_year['risk_ratio'].mean().plot(kind='line')
plt.show()


plt.figure(figsize=(12, 14))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False) 
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()

# %% [markdown]
# ## Analysis on Risk:

# %% [markdown]
#  ## Investigation of Insight

# %%
insight_dict = get_dict(dict_df, "insight")

# %%
lyrics_df['insight_count'] = lyrics_df['tokens_lower_clean'].apply(lambda x: dict_count(x, insight_dict))

# %%
lyrics_df['insight_ratio'] = lyrics_df['insight_count'] / lyrics_df['token_count']

# %%
groupedby_year = lyrics_df.groupby('year')

# %%
groupedby_year['insight_ratio'].mean().plot(kind='line')
plt.show()

plt.figure(figsize=(12, 14))   
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False) 
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()

# %% [markdown]
# ## Analysis on Insight:

# %% [markdown]
# # III. Overview Analysis on Intersectionality of Themes
#
# Our hypothesis dictated certain expectations for how LIWC dictionaries would validate changes in rap and hip-hop lyrical themes as the genre entered the mainstream. We believed that would would see increases in the lyrical reference to money, sex, leisure, and swear words. Furthermore, we believed that by entering the mainstream, commentary and reflection on meaningful experiences would decrease. To validate this, we expected lyrical reference to power, anger, risk, and insight to decrease.
#
# What we found was that there has been increasing reference to money, sex, anger, and swear words. No topics have been experiencing a decreasing reference. Otherwise, lyrical references to insight, risk, leisure, and power have remained relatively stable, though do experience aggressive variation year to year.
#
# Another notable intersectionality is that some year share similar peaks and valleys. For examples the year 2008 saw drops in power, sex, leisure, and risk. Could this have been a product of the housing crisis? Another example is that in 2003, we saw major drops in reference to money, power, sex, and anger but major gains in insight and risk. Could this have been a response to the 9/11 attacks and War on Terror? Further anaylsis is needed.

# %% [markdown]
# # Conclusion:
#
# We believe that through the means we have choosen to interpret our data our hypothesis (that rap and hip-hop lyrics have shifted to more relay more commercialized sentiments) is supported. We originally stated that we believed that we will see a trend in lyrical content pivoting from the iteration of black American experience to conventional themes in popular music such as love/sex, fame, and status/power. This hypothesis manifests as we note that trends in reference to money, sex, anger, and swear words are gradually increasing. Nevertheless, our hypothsis is not 100% supported as the commercialized sentiment of leisure has stayed relatively stable, along with the other topics of power, anger, risk, and insight that we expected to decrease. Furthermore, it is important to reiterate that much of the methods that we relied on are subject to personal analysis.
#
# Taking this into consideration, one of our biggest take aways is that though there seem to be general trends of increased consumerim, the variation in years can be strikingly subjective to change. For example, in the "Insights" graph we see stark peaks and valleys that are almost exclusively contained within singular years. We interpret this finding to be a product of sociological influences and we believe that there is much potential for further investigation into why we see such variation year to year. We believe that future iterations of this project could benefit from an anthropological approach similar to the documentory "Hip-Hop Evolution" that traces notable thematic changes through interviews and qualative data.
#
#
# ## Limitations
#
# - Subjective creation of LIWC dictionaries
# - Bias application/interpretation of LIWC dictionaries
# - Bias interpretation of topic modeling (influenced from preconceptions from previous research)
# - Bias interpretation of graphs of lyrical references
# - Rap and hip-hop have many colloqualism that may have not been accounted for
# - We could have overlooked certain sociological influence that caused such fluxuations
#
# ## Future Computational Steps
#
# If we had more time there are several directions we would take this project in. Some of the ideas that we are interested in pursuing include:
#
# - See how trends in the themes we have identified in mainstream rap and hip-hop have been reflected in other popular genres, are they affected by the same sociological events
# - See how trends in the themes we have identified are mediated by technological innovations in rap and hip-hop
# - Use the concordanance function to look at specific lyrics in order to validate the specific referenced sociological assocations
# - It would be interesting to plot trends that compare to negative emotions to patterns of money and power, and how they overlap with our proposed sociological explanations
# - Addressing some of the limitations we cited above through extended computational analysis
# - Created graphs that would compare all the topics on one axis

# %% [markdown]
# # Work Cited
#
# - Amadeo, K. (2017, April 07). Stock Market Crash of 2008. Retrieved May 07, 2017, from https://www.thebalance.com/stock-market-crash-of-2008-3305535
#
# - CNN, & Reuters. (Aug 26, 2004). Census Bureau says 1.3 million more Americans in poverty. Retrieved May 07, 2017, from http://money.cnn.com/2004/08/26/news/economy/poverty_survey/
#
# - Cullors, P., Garza, A., & Tometi, O. (n.d.) About the Black Lives Matter Network. Retrieved May 08, 2017, from http://blacklivesmatter.com/about/.
#
# - Graaf, G. & Ratliff, A. (2017). Social Welfare Policy, SW 112. Lecture presented in McCone Hall, at University of California, Berkeley.
#
# - Kabango, S. (Director). (2016, September 4). Hip-Hop Evolution [Video file]. Retrieved May 5, 2017, from http://hiphopevolution.com/pages/about-the-series/
#
# - Lichtblau, E. (2016, September 17). Hate Crimes Against American Muslims Most Since Post-9/11 Era. Retrieved May 08, 2017, from https://www.nytimes.com/2016/09/18/us/politics/hate-crimes-american-muslims-rise.html
#
# - Roberts, J. (2002, September 04). Plans For Iraq Attack Began On 9/11. Retrieved May 08, 2017, from http://www.cbsnews.com/news/plans-for-iraq-attack-began-on-9-11/
#
# - Schuelke, R. (2003, December 30). Timeline of Key Economic Events in 2003. Retrieved May 07, 2017, from http://www.sonic.net/~schuelke/EconomicEvents2003.html
#
# - Graham, J. (2016). What Happened in 2010. Retrieved May 07, 2017, from http://www.onthisday.com/date/2010
