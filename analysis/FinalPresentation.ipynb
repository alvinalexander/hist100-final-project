# %% [markdown]
# # The Question
#
# Hip-hop and rap is a genre that has had an unprecedented origins and evolution in the past forty years. “Hip-Hop Evolution” is a documentary series that does an incredible job in tracking the origins and early manifestations of rap and hip-hop. Their story starts in the Bronx of New Year City and follows the largest visionaries and musical innovators of the time up till the 1992, when rap officially enters the “mainstream". The documentary functions as an anthropological escapade, relying on interviews with a broad range of individuals involved in the genre’s creation. It pieces together a narrative that explains how rap and hip hop emerged as both a technological and sociological innovation-- tracking lyrical themes starting from its primary, exclusive purpose as party entertainment to how it became a medium to propose commentary and reflection on the reality of poor neighborhoods and being Black American at the time. Though we believe this project has done an impressive job in tracing rap and hip-hops origins, our project is interested in investigating the evolution of the genre after where the series ends.
#
# We want to know how has rap and hip-hop has evolved since it entered the mainstream? How does this differ from its underground roots? And what sociological and technological events have motivated recent modifications?
#
# ### Our hypothesis
#
# The documentary suggests that rap and hip-hop is a genre that has always been concerned with commenting and reflecting on reality.
#
# The flim cites that the genre first manifested as a product of disco and partying, where MCs dominated the social scene and wrote music about partying and women that resulting served as assertions of status. After the song, “The Message” by Grandmaster Flash and The Furious Five came out in 1982, rap and hip-hop saw a glimpse of what the top songs in the coming decade would discuss. The 1980s was a dynamic and difficult time for urban America, especially for impoverished black communities. Reaganomics, the emergence of crack, the War on Drugs, gang violence, and discrimination all had tremendous influence, and it was during this period, that for the first time, these issues began manifesting themselves as lyrical topics in music.
#
#
# Furthermore, as the documentary series comes to a close, it discusses how the popularity of rap and hip hop was permeating into young neighborhoods throughout the United States. The heightened popularity seen in early 1990s set presidency for a new type of rap and hip-hop as rappers transitioned from underground artists to reaping the same fame and notoriety of pop stars.
#
# Give this consideration, we also hypothesize that as rap and hip-hop enter the mainstream in the early 1990s, we will see an increase in lyrical content that pivots from the iteration of black American experience to vague lyrical content of conventional popular music such as love, fame, and status.
#
#
#
# # Background on the Corpus
#
# We composed our corpus of rap lyrics by first making a list of all the rap songs that have appeared on the Billboard Hot Rap Songs list from 1989-2016 (http://www.billboard.com/charts/rap-song).
#
# To get the lyrics, we wrote a script that scraped 2317 lyrics from the well-established lyrics site Rap Genius(https://genius.com). That is about 81% of all the songs that appears on the list during the specified time period. The figure bellow illustrated how the lyrics are distributed across time. Our corpus also necessitated computtational cleaning in removing variables such as uppercase letters, punctuation, etc..
#
# This data collection functions as an appropriate selection for our investigation as we are interested in tracking how recent manifestations of hip-hop and rap have evolved as (A) a product of being in the mainstream (hence why we selected Billboard Hot Rap Songs), and  (B) through sociological and technological conditions of the time (we wanted to study influences after 1994, where the documentary series “Hip-Hop Evolution" leaves off.
#
#
# # Through What Means
#
# Our project first starts with topic-modeling, as we are looking to partially corroborate the themes noted throughout the documentary film “Hip-Hop Evolution”.
#
# After this we will be examining the more specific elements of our investigation, comparing thematic changes over time, and noting relavant changes as rap enters the mainstream. SOme of these emerages as obvious topics, dont really investgate, some are more encaompassing and these are the ones of interest, We see a few topic emerges with extreme positive progress.
#
# Next we will be using LIWC dictionary to inveigates topics of interest. After identifying notables term/were concordance, how are these words are being used in specific context. Specific

# %%
from ast import literal_eval
import pandas
import matplotlib.pyplot as plt
import numpy as np
import nltk 
from time import time
df = pandas.read_csv("../data/bbtop15-lyrics-tokenized.csv",converters={'tokens_lower':literal_eval, 'tokens_lower_clean':literal_eval } )

#drop rows where the text is missing.
df = df.dropna(subset=['lyrics'])
df = df.query('1990 < year < 1995')

#view the dataframe
df
# Out:
#      track_id                                      track  \
# 110       166                                Gold Digger
# 111       168                      Play That Funky Music
# 112       169                        Crumbs On The Table
# 113       170                    The Devil Made Me Do It
# 114       171                            Treat 'Em Right
# 115       172                         Melt In Your Mouth
# 116       173                             Can I Kick It?
# 117       174                                    Wake Up
# 118       177                          Just To Get A Rep
# 119       178                      Here Comes The Hammer
# 120       179                               Erase Racism
# 121       180                            Dance All Night
# 122       181                                 Rico Suave
# 123       182                     Come On, Let's Move It
# 124       183                             Do You Want Me
# ...

# %%
text_objects = [nltk.Text(tokens) for tokens in df['tokens_lower_clean'].tolist()]

# %%
con_money = [text.concordance('money') for text in text_objects if text.concordance('money') != None or text.concordance('money') != 'No matches']
clean = [x for x in con_money if x != 'No Matches']
# Out:
# Displaying 3 of 3 matches:
# ke cement i have no files on all the money she spent she has a car nineteen nin
# my bank account gettin more and more money she got paid it wasnt funny talkin t
# e cash oh yes the whole damn bash of money so i chill and act so sweet kiss her
# Displaying 3 of 3 matches:
# ke cement i have no files on all the money she spent she has a car nineteen nin
# my bank account gettin more and more money she got paid it wasnt funny talkin t
# e cash oh yes the whole damn bash of money so i chill and act so sweet kiss her
# Displaying 3 of 3 matches:
# ke cement i have no files on all the money she spent she has a car nineteen nin
# my bank account gettin more and more money she got paid it wasnt funny talkin t
# e cash oh yes the whole damn bash of money so i chill and act so sweet kiss her
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# ...

# %%
similar_money = [text.similar('money') for text in text_objects if text.similar('money') != None ]
clean = [x for x in con_money if x != 'No Matches']
# Out:
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
#
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
# nothin
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
#
#
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
#
# No matches
#
# No matches
#
# fool
#
# No matches
#
#
#
# No matches
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
# body
# No matches
# No matches
# keys caps bitches
#
# No matches
#
#
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
# No matches
#
# No matches
#
# No matches
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
# ...

# %% [markdown]
# ### Similiar Words to Money 1991 - 1994
#
# gold, writings, block driver car tank hammer nine, clothes, mic, cars, poor, keys caps bitches, fool, nothin, breath, sky, worm dogs, mind, woman

# %%
df = pandas.read_csv("../data/bbtop15-lyrics-tokenized.csv",converters={'tokens_lower':literal_eval, 'tokens_lower_clean':literal_eval } )

#drop rows where the text is missing.
df = df.dropna(subset=['lyrics'])
df = df.query('1994 < year < 2001')

#view the dataframe
df
# Out:
#       track_id                                     track  \
# 522        712                                     Vocab
# 523        713                                 Cocktales
# 524        714                         Nuttin But Flavor
# 525        715                                      Nika
# 526        716                         Big Poppa/Warning
# 527        717                                   Mad Izm
# 528        721                                 Proceed I
# 529        722                                  Oh Yeah!
# 530        723                                 Supa Star
# 531        724                             Heaven & Hell
# 532        725                                   No Hook
# 533        726                                     1-Luv
# 534        727                         Foe The Love Of $
# 535        728                              Brooklyn Zoo
# 536        729                        Shook Ones Part II
# ...

# %%
text_objects = [nltk.Text(tokens) for tokens in df['tokens_lower_clean'].tolist()]
similar_money = [text.similar('money') for text in text_objects if text.similar('money') != None ]
clean = [x for x in similar_money if x != 'No Matches']
# Out:
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
#
# No matches
# No matches
#
# No matches
#
# No matches
# No matches
# No matches
#
#
# No matches
#
#
#
#
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
#
#
# No matches
# No matches
# No matches
# No matches
# one
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
# No matches
#
# No matches
# No matches
#
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# ...

# %% [markdown]
# ### Similiar Words to Money 1995 - 2000
#
# - chick
# - cars
# - trampled
# - cash
# - records
# - Pussy
# - drugs
# - laugh math
# - fuck
# - fantasies
# - problems
# - bop hop
# - lie
# - momma

# %%
df = pandas.read_csv("../data/bbtop15-lyrics-tokenized.csv",converters={'tokens_lower':literal_eval, 'tokens_lower_clean':literal_eval } )

#drop rows where the text is missing.
df = df.dropna(subset=['lyrics'])
df = df.query('1999 < year < 2006')

#view the dataframe
df
# Out:
#       track_id                                      track  \
# 937       1266                             N 2 Gether Now
# 938       1271                                Best Friend
# 939       1272                                Freakin' It
# 940       1273                                The Express
# 941       1274  That's What I'm Looking For/What'Chu Like
# 942       1275                             Got Your Money
# 943       1277                    Whistle While You Twurk
# 944       1278                      Party Up (Up In Here)
# 945       1280                                      Whoa!
# 946       1281                              The 6th Sense
# 947       1283                               The Platform
# 948       1284                 (Hot S**t) Country Grammar
# 949       1286                                   Ill Bomb
# 950       1287                                   Imperial
# 951       1289                               It's So Hard
# ...

# %%
text_objects = [nltk.Text(tokens) for tokens in df['tokens_lower_clean'].tolist()]
similar_money = [text.similar('money') for text in text_objects if text.similar('money') != None ]
clean = [x for x in similar_money if x != 'No Matches']
# Out:
# No matches
# No matches
#
# No matches
# No matches
#
#
# No matches
#
#
# No matches
#
#
# No matches
#
#
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
#
#
# No matches
# No matches
# No matches
# No matches
#
#
# No matches
#
# No matches
# No matches
#
#
# No matches
#
#
#
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
#
#
# No matches
# No matches
#
# No matches
# No matches
#
#
#
#
# No matches
# No matches
#
#
#
# No matches
# No matches
#
#
#
# No matches
# chick
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
#
#
#
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# ...

# %% [markdown]
# ### Similiar Words to Money 2000 - 2005
#
# - chick
# - nothin
# - farm haystack
# - fifty
# - for
# - leather keyboard
# - border
# - lap
# - queens brooklyn jersey bronx boston gangsta
# - chick
# - ly silly
# - crimey
# - life
# - face

# %%
df = pandas.read_csv("../data/bbtop15-lyrics-tokenized.csv",converters={'tokens_lower':literal_eval, 'tokens_lower_clean':literal_eval } )

#drop rows where the text is missing.
df = df.dropna(subset=['lyrics'])
df = df.query('2004 < year < 2011')

#view the dataframe
df
# Out:
#       track_id                            track  \
# 1326      1786                         Gasolina
# 1327      1787                  U Don't Know Me
# 1328      1788                  Let's Get Blown
# 1329      1790                      Pretty Girl
# 1330      1791                      Mockingbird
# 1331      1792                       Candy Shop
# 1332      1793                             Hope
# 1333      1794               Sugar (Gimme Some)
# 1334      1795                     Down And Out
# 1335      1796               Hate It Or Love It
# 1336      1797                     I'm A Hustla
# 1337      1798          Wait (The Whisper Song)
# 1338      1799                    Baby I'm Back
# 1339      1800                  Number One Spot
# 1340      1801                    Still Tippin'
# 1341      1802                             Toma
# 1342      1803                     So Much More
# 1343      1804                   Just A Lil Bit
# ...

# %%
text_objects = [nltk.Text(tokens) for tokens in df['tokens_lower_clean'].tolist()]
similar_money = [text.similar('money') for text in text_objects if text.similar('money') != None ]
clean = [x for x in similar_money if x != 'No Matches']
# Out:
# No matches
# No matches
# No matches
# No matches
#
# No matches
#
# No matches
#
#
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# life
#
# No matches
# No matches
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
#
# face
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
#
#
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
#
# No matches
#
#
# No matches
# No matches
# No matches
#
#
# No matches
# No matches
#
# No matches
# No matches
#
#
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
#
# No matches
#
#
#
#
# No matches
#
#
# No matches
#
# No matches
#
# No matches
# No matches
# No matches
# ...

# %% [markdown]
# ### Similiar Words to Money 2000 - 2010
#
# - life
# - face
# - way boss
# - glow
# - bitch
# - cases
# - pots white
# - yeah i
# - around
# - house shit
# - fire fact
# - paid
# - shoes liiiife
# - honey
# - blow floor
# - mall
# - fire
# - top
# - rice
# - monkey
# - stacks ceo
# - numbers
# - easter stunting them
# - look feel sound
# - nigga
# - honey
# - dick
# - moneys
# - tax
# - road
# - bottles
# - lol dadadadadadada

# %%
df = pandas.read_csv("../data/bbtop15-lyrics-tokenized.csv",converters={'tokens_lower':literal_eval, 'tokens_lower_clean':literal_eval } )

#drop rows where the text is missing.
df = df.dropna(subset=['lyrics'])
df = df.query('2010 < year < 2016')

#view the dataframe
df
# Out:
#       track_id                                   track  \
# 1770      2254                           6 Foot 7 Foot
# 1771      2255                             Coming Home
# 1772      2256                       All Of The Lights
# 1773      2259                Ain't Thinkin' 'Bout You
# 1774      2260                      Welcome To My Hood
# 1775      2261                        The Show Goes On
# 1776      2262                          Look At Me Now
# 1777      2263                                Backseat
# 1778      2264                         Grove St. Party
# 1779      2265                     I Don't Deserve You
# 1780      2266                            Did It On'em
# 1781      2267                             Hustle Hard
# 1782      2268                                 Roll Up
# 1783      2269                         I Need A Doctor
# 1784      2270                                   Racks
# 1785      2271                                 My Last
# ...

# %%
text_objects = [nltk.Text(tokens) for tokens in df['tokens_lower_clean'].tolist()]
similar_money = [text.similar('money') for text in text_objects if text.similar('money') != None ]
clean = [x for x in similar_money if x != 'No Matches']
# Out:
# numbers
# No matches
# easter stunting them
# No matches
# No matches
# No matches
#
#
#
# No matches
# No matches
#
#
#
# No matches
#
#
# No matches
# No matches
# No matches
#
# look feel sound
#
# No matches
# No matches
#
# No matches
#
# No matches
#
# No matches
#
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
#
#
#
# nigga
# No matches
#
# No matches
#
# honey
# No matches
# No matches
# dick
#
# No matches
# moneys
#
#
# tax
#
# No matches
#
#
# No matches
# No matches
#
# road
#
# No matches
# No matches
#
# No matches
# No matches
#
# No matches
# bottles
#
# No matches
# lol dadadadadadada
#
#
# No matches
#
#
# No matches
#
# No matches
#
#
#
#
#
# No matches
# way
# No matches
#
#
#
# No matches
#
# No matches
# No matches
#
# No matches
#
#
#
# No matches
# No matches
# No matches
# No matches
# No matches
#
# No matches
# No matches
#
#
#
# No matches
# No matches
#
# No matches
#
# No matches
# bank power
#
# No matches
# ...

# %% [markdown]
# ### Similiar Words to Money 2010 - 2015
#
# - numbers
# - easter stunting them
# - easter stunting them
# - look feel sound
# - nigga
# - honey
# - dick
# - moneys
# - tax
# - road
# - bottles
# - lol dadadadadadada
# - way
# - bank
# - liquor
# - dirty
# - garbage
# - hustle
# - tunechi pussy
# - kitchen
# - blood
# - crib
# - homies
# - coupe
# - im
# - last
# - your
# - door
# - stripper girls
# - shit
# - real
# - day ropes
# - baby
# - car
# - cold

# %% [markdown]
# # Future Steps
#
# Our hypothesis is to assume that this will continue to be true in more recent interactions. We want consider how the following social event influenced rap and hip hop lyrics.
# - Hurricane Katrina
# - Donald Trump
# - Black Lives Matter / Trevone Martin / George Zimmerman
# - 99% Protest
# - Rodney King Riots
